# %%
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## 이미지 파일 열기

# %% [markdown]
# opencv로도 열수 있지만, shape 순서가 바뀔 때도 있어서 PIL로 여는 것을 선호

# %%
path = 'C:/Users/신상훈/Desktop/새 폴더/dog.jpg'

image_pil = Image.open(path)
image = np.array(image_pil)

# %%
image.shape # 3차원 3은 색상
# Out:
# (734, 1100, 3)

# %% [markdown]
# ## 이미지 들여다보기

# %%
image.shape
# Out:
# (734, 1100, 3)

# %%
np.min(image),np.max(image)
# Out:
# (0, 255)

# %% [markdown]
# ## 그래프로 시각화 하기

# %%
plt.hist(image.ravel(),256,[0,256])
plt.show()

# %% [markdown]
# ## 그림 나타내기

# %%
plt.imshow(image)
plt.show()

# %% [markdown]
# ## 이미지 흑백으로 열기

# %%
image_pil = Image.open(path).convert("L")
image_bw = np.array(image_pil)

# %%
image_bw.shape
# Out:
# (734, 1100)

# %%
plt.imshow(image_bw,'gray')
plt.show()

# %% [markdown]
# ---
# ### 다른 색상으로 cmap 표현하기

# %% [markdown]
# ### gray scale

# %%
image.shape
# Out:
# (734, 1100, 3)

# %%
plt.imshow(image)
plt.show()

# %%
plt.imshow(image_bw)
plt.show()

# %%
plt.imshow(image_bw,'gray')
plt.show()

# %% [markdown]
# ### RdBu

# %%
plt.imshow(image_bw,'RdBu')
plt.show()

# %% [markdown]
# ### jet

# %%
plt.imshow(image_bw,'jet')
plt.show()

# %% [markdown]
# ---
# ## Colorbar 추가하기

# %%
plt.imshow(image_bw,'jet')
plt.colorbar()
plt.show()

# %% [markdown]
# ---
# ## 이미지 설정

# %% [markdown]
# 이미지 보기 사이즈 조절

# %%
plt.figure(figsize=(10,5))
plt.imshow(image_bw,'jet')
plt.colorbar()
plt.show()

# %% [markdown]
# ---
# ## 이미지에 제목 추가

# %%
plt.figure(figsize=(10,5))
plt.imshow(image_bw,'jet')
plt.colorbar()
plt.title('dog')
plt.show()

# %% [markdown]
# # 두번째 이미지 열기

# %%
cat_path = 'C:/Users/신상훈/Desktop/새 폴더/cat.jpg'

cat_image_pil = Image.open(cat_path)
cat_image = np.array(cat_image_pil)

# %%
plt.imshow(cat_image)
plt.show()

# %%
cat_image.shape, image.shape #shape가 맞지 않는다.
# Out:
# ((183, 275, 3), (734, 1100, 3))

# %% [markdown]
# ## 두번째 이미지 합치기 위한 준비

# %%
import cv2

# %%
dog_image = cv2.resize(image,(275,183))
dog_image.shape
# Out:
# (183, 275, 3)

# %%
dog_image.shape, cat_image.shape
# Out:
# ((183, 275, 3), (183, 275, 3))

# %%
plt.imshow(dog_image)
plt.imshow(cat_image)
plt.show()

# %%
plt.imshow(dog_image)
plt.show()
plt.imshow(cat_image)
plt.show()

# %%
plt.imshow(dog_image)
plt.imshow(cat_image,alpha=0.5)
plt.show()

# %% [markdown]
# ## subplot

# %%
plt.figure(figsize=(10,10))
plt.subplot(221)
plt.imshow(image)
plt.subplot(222)
plt.imshow(image_bw,'gray')
plt.subplot(223)
plt.imshow(cat_image)
plt.show()
